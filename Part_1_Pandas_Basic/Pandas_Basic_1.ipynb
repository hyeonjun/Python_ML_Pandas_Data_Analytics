# %% [markdown]
# # 판다스
#
# 데이터를 수집하고 정리하는 데 최적화된 도구.
#
# 판다스를 사용하여 데이터 과학의 80~90% 업무를 처리할 수 있고, 데이터 과학자에게 필요한 기본적이면서도 아주 중요한 도구이다.
#
# # 판다스 자료구조
#
# 분석을 위해 다양한 소스로부터 수집하는 데이터는 형태나 속성이 매우 다양하다. 특히 서로 다른 형식을 갖는 여러 종류의 데이터를 컴퓨터가 이해할 수 있도록 동일한 형식을 갖는 구조로 통합할 필요가 있다.
#
# 이를 위해 판다스는 시리즈(Series)와 데이터프레임(DataFrame)이라는 구조화된 데이터 형식을 제공한다. 서로 다른 종류의 데이터를 한 곳에 담는 그릇(컨테이너)이 된다. 다만 시리즈는 1차원 배열이고, 데이터프레임이 2차원 배열이라는 점에서 차이가 있다.
#
# 판다스의 1차적인 목적은 서로 다른 여러 가지 유형의 데이터를 공통의 포맷으로 정리하는 것이다. 특히 행과 열로 이루어진 2차원 데이터프레임은 데이터 분석 실무에서 자주 사용된다.
#
# # 시리즈
#
# 시리즈는 데이터가 순차적으로 나열된 1차원 배열의 형태를 갖는다.
#
# 인덱스(index)는 데이터 값(value)과 일대일 대응이 된다.
#
# 이런 관점에서 키(k)와 값(v)이 '{k:v}' 형태로 짝을 이루는 파이썬 딕셔너리와 비슷한 구조를 갖는다고 볼 수 있다.
#
# 이처럼 시리즈의 인덱스는 데이터 값의 위치를 나타내는 데이터 주소 역할을 한다.
#
# ![image.png](data:image/png;base64,...)
#
# * 시리즈 만들기 (딕셔너리 -> 시리즈 변환)
#
# ```
#  pandas.Series(딕셔너리)
# ```
# 딕셔너리의 키(k)는 시리즈의 인덱스에 대응하고, 값은 시리즈의 데이터 값으로 변환된다.
#
# ![image.png](data:image/png;base64,...)

# %%
# 딕셔너리 -> 시리즈 변환

import pandas as pd

# key:value 쌍으로 딕셔너리를 만들고, 변수 dict_data에 저장
dict_data = {'a':1, 'b':2, 'c':3}

# 판다스 Series() 함수로 dictionary를 Series로 변환. 변수 sr에 저장
sr = pd.Series(dict_data)

# %%
# sr의 자료형 출력
type(sr)
# Out:
# pandas.core.series.Series

# %%
sr
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# *  인덱스 구조
#
# 인덱스는 자기와 짝을 이루는 데이터 값의 순서와 주소를 저장한다. 인덱스를 잘 활용하면 데이터 값의 탐색, 정렬, 선택, 겹합 등 데이터 조작을 쉽게 할 수 있다.
#
# 인덱스에는 크게 두 가지 동류가 있다. 정수형 위치 인덱스(Integer position)와 인덱스 이름(index name) 또는 인덱스 라벨(index label).
#
# ![image.png](data:image/png;base64,...)
#
# 시리즈 클래스의 index 속성을 이용하여 인덱스 배열을 따로 선택할 수 있다.
# ```
#  인덱스 배열 : Series.index
# ```
#
# 또한 데이터 값 배열만을 따로 선택할 수도 있다. 시리즈 클래스의 values 속성을 이용한다.
# ```
#  데이터 값 배열 : Series.values
# ```
#
# 판다스 Series() 함수를 사용하여 파이썬 리스트를 시리즈로 변환한다. 단, 리스트를 시리즈로 변환할 때는 딕셔너리의 키처럼 인덱스로 변환될 값이 없다. 따라서 인덱스를 별도로 정의하지 않으면, 디폴트로 정수형 위치 인덱스(0, 1, 2, ...)가 자동으로 지정된다.

# %%
import pandas as pd

# 리스트를 시리즈로 변환하여 변수 sr에 저장
list_data = ['2019-01-02', 3.14, 'ABC', 100, True]
sr = pd.Series(list_data)

# %%
sr
# Out:
# 0    2019-01-02
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
# 시리즈의 index와 values 속성을 이용하면 인덱스 배열과 데이터 값의 배열을 불러올 수 있다.
idx = sr.index
val = sr.values

# %%
idx
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
val
# Out:
# array(['2019-01-02', 3.14, 'ABC', 100, True], dtype=object)

# %% [markdown]
# * 원소 선택
#
# 원소의 위치를 나타내는 주소 역할을 하는 인덱스를 이용하여 시리즈의 원소 선택.
#
# 하나의 원소 또는 여러 원소를 선택할 수 있다. 파이썬 리스트 슬라이싱 기법과 비슷하게 인덱스 범위를 지정하여 원소를 선택하는 방법도 있다.
#
#
# Series() 함수를 사용하여 파이썬 튜플(tuple)을 시리즈로 변환한다.
# 이번에는 Series() 함수의 index 옵션을 사용하여 인덱스 이름을 직접 전달하는 방식으로 변환한다.

# %%
import pandas as pd

# 튜플을 시리즈로 변환(인덱스 옵션 지정)
tup_data = ('현준', '1995-08-10','남',True)
sr = pd.Series(tup_data, index=['이름', '생년월일', '성별', '학생여부'])

# %%
sr
# Out:
# 이름              현준
# 생년월일    1995-08-10
# 성별               남
# 학생여부          True
# dtype: object

# %%
# 인덱스를 활용하여 원소 선택 시 [] 안에 인덱스를 입력한다.
# 정수형 위치 인덱스로 0을, 인덱스 라벨로 '이름'을 입력하면 모두 같은 원소를 반환한다.
print(sr[0])
print(sr['이름'])
# Out:
# 현준
# 현준

# %%
# 여러 개의 원소 선택 - 인덱스 리스트 활용
print(sr[[1, 2]])
print(sr[['생년월일', '성별']])
# Out:
# 생년월일    1995-08-10
# 성별               남
# dtype: object
# 생년월일    1995-08-10
# 성별               남
# dtype: object

# %%
# 여러 개의 원소 선택 - 인덱스 범위 지정
print(sr[1:2])
print(sr['생년월일':'성별'])
# Out:
# 생년월일    1995-08-10
# dtype: object
# 생년월일    1995-08-10
# 성별               남
# dtype: object

# %% [markdown]
# * 데이터프레임 - 2차원 배열
#
# 데이터프레임의 열은 각각 시리즈 객체이다. 시리즈를 열벡터라고 하면, 데이터프레임은 여러 개의 열벡터들이 같은 행 인덱스를 기준으로 줄지어 결합된 2차원 벡터 or 행렬이다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 데이터프레임은 행의 인덱스(row index)와 열의 이름(column name 또는 column label)으로 구분한다. 데이터프레임의 열은 공통의 속성을 갖는 일련의 데이터를 나타내고, 행은 개별 관측대상에 대한 다양한 속성 데이터들의 모음인 레코드(record)가 된다.
#
# * 데이터프레임 만들기
#
# 데이터프레임을 만들기 위해서는 같은 길이의 1차원 배열 여러 개가 필요하다.
#
# ![image.png](data:image/png;base64,...)
#
# ```
#  딕셔너리 -> 데이터프레임 변환: pandas.DataFrame(딕셔너리 객체)
# ```

# %%
import pandas as pd
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], 'c3':[10,11,12], 'c4':[13,14,15]}

# DataFrame() 함수로 딕셔너리를 데이터프레임으로 변환.
df = pd.DataFrame(dict_data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    c0  c1  c2  c3  c4
# 0   1   4   7  10  13
# 1   2   5   8  11  14
# 2   3   6   9  12  15

# %% [markdown]
# * 행 인덱스 / 열 이름 지정
#
# ```
#  행 인덱스/열 이름 설정 : pandas.DataFrame(2차원 배열,
#                                             index=행 인덱스 배열,
#                                             columns=열 이름 배열
# ```

# %%
import pandas as pd
df = pd.DataFrame([[15,'남','덕영중'], [17,'여','수리중']],
                  index=['준서','예은'],
                  columns=['나이','성별','학교'])

# %%
df
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
df.index
# Out:
# Index(['준서', '예은'], dtype='object')

# %%
df.columns
# Out:
# Index(['나이', '성별', '학교'], dtype='object')

# %% [markdown]
# 데이터프레임 df의 행 인덱스는 df.index 속성으로 접근하고, 행 인덱스 배열을 구성하는 원소와 자료형을 알 수 있다.
#
# 데이터프레임 df의 행 인덱스와 열 이름 객체를 나타내는 df.index와 df.columns의 속성에 새로운 배열을 할당하는 방식으로 행 인덱스와 열 이름을 변경할 수 있다
#
# ```
#  행 인덱스 변경 : DataFrame.index = 새로운 행 인덱스 배열
#  열 이름 변경 : DataFrame.columns = 새로운 열 이름 배열
# ```

# %%
df.index=['학생1', '학생2']
df.columns=['연령','남녀','소속']

# %%
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
df.index
# Out:
# Index(['학생1', '학생2'], dtype='object')

# %%
df.columns
# Out:
# Index(['연령', '남녀', '소속'], dtype='object')

# %% [markdown]
# 데이터프레임의 rename() 메소드를 적용하면 행 인덱스 도는 열 이름의 일부를 선택하여 변경 할 수 있다. 단, 원본 객체를 직접 수정하는 것이 아니라 새로운 데이터프레임 객체를 반환하는 점을 유의! 원본 객체를 변경하려면 inplace=True 옵션을 사용한다.
#
# ```
#  행 인덱스 변경 : DataFrame.rename(index={기존 인덱스 : 새 인덱스, ...}
#  열 이름 변경 : DataFrame.rename(columns={기존 이름 : 새 이름, ...}
# ```

# %%
import pandas as pd

# 행 인덱스/열 이름 지정하여, 데이터프레임 만들기
df = pd.DataFrame([[15, '남', '덕영중'], [17, '여', '수리중']], 
                   index=['준서', '예은'],
                   columns=['나이', '성별', '학교'])

# 열 이름 중, '나이'를 '연령'으로, '성별'을 '남녀'로, '학교'를 '소속'으로 바꾸기
df.rename(columns={'나이':'연령', '성별':'남녀', '학교':'소속'}, inplace=True)

# df의 행 인덱스 중에서, '준서'를 '학생1'로, '예은'을 '학생2'로 바꾸기
df.rename(index={'준서':'학생1', '예은':'학생2' }, inplace=True)

# %%
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %% [markdown]
# * 행/열 삭제
#
# drop() - 데이터프레임의 행 또는 열을 삭제하는 명령
#
# 행을 삭제할 때는 축(axis) 옵션을 axis=0을 입력하거나, 별도로 입력하지 않는다.
#
# 열을 삭제할 때는 축 옵션을 axis=1을 넣어주어야 한다.
#
# 동시에 여러 개의 행 또는 열을 삭제하려면 리스트 형태로 입력한다.
#
# 주의. drop() 메소드는 기존 객체를 변경하지 않고 새로운 객체를 반환한다. 원본 객체를 변경하려면 inplace=True 옵션을 사용.

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}

df = pd.DataFrame(exam_data, index=['서준', '우현', '인아'])
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
df2 = df[:] # df를 복제하여 변수 df2에 저장
df2.drop('우현', axis=0, inplace=True) # 1개의 행 삭제
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90

# %%
df3 = df[:]
df3.drop(['우현','인아'], inplace=True)
df3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
df4 = df[:]
df4.drop('수학', axis=1, inplace=True)
df4
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     영어   음악   체육
# 서준  98   85  100
# 우현  89   95   90
# 인아  95  100   90

# %%
df5 = df[:]
df5.drop(['영어','음악'], axis=1, inplace=True)
df5
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %% [markdown]
# * 행 선택 - loc, iloc
#
# 인덱스 이름을 기준으로 행을 선택 -> loc
#
#  => 범위 지정 : ['a' : 'c']
#
# 정수형 위치 인덱스를 기준으로 행을 선택 -> iloc
#
#  => 범위 지정 : [3 : 7]

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'수학' : [ 90, 80, 70], '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100], '체육' : [ 100, 90, 90]}

df = pd.DataFrame(exam_data, index=['서준', '우현', '인아'])
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
label1 = df.loc['서준']
position1 = df.iloc[0]

# %%
label1
# Out:
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
position1
# Out:
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
label2 = df.loc[['서준', '우현']]
position2 = df.iloc[[0, 1]]

# %%
label2
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90

# %%
position2
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90

# %%
label3 = df.loc['서준' : '우현']
position3 = df.iloc[0 : 1]

# %%
label3
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90

# %%
position3
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %% [markdown]
# * 열 선택
#
# 데이터프레임의 열 데이터를 1개만 선택할 때는 [] 안에 열 이름을 따옴표와 함께 입력 또는 . 다음에 열 이름을 입력하는 두 가지 방식을 사용한다.
#
# . 를 사용하는 방법은 반드시 열 이름이 문자열일 경우에만 사용 가능.

# %%
import pandas as pd

exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}

df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
math1 = df['수학']
math1
# Out:
# 0    90
# 1    80
# 2    70
# Name: 수학, dtype: int64

# %%
type(math1)
# Out:
# pandas.core.series.Series

# %%
english = df.영어
english
# Out:
# 0    98
# 1    89
# 2    95
# Name: 영어, dtype: int64

# %%
type(english)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 위 처럼 하나의 열을 가져오면 시리즈 객체가 반환된다.
#
# 데이터프레임에서 2개 이상의 열을 추출하는 방법 : [['열이름','열이름']]
#
# 이렇게 2중 배열을 사용하여 추출하게 되면 열 1개를 입력하여도 시리즈가 아닌 데이터프레임을 반환한다.

# %%
music_gym =df[['음악', '체육']]
music_gym
# Out:
#     음악   체육
# 0   85  100
# 1   95   90
# 2  100   90

# %%
type(music_gym)
# Out:
# pandas.core.frame.DataFrame

# %%
math2 = df[['수학']]
type(math2)
# Out:
# pandas.core.frame.DataFrame

# %%
math2
# Out:
#    수학
# 0  90
# 1  80
# 2  70

# %% [markdown]
# * 원소 선택
#
# 데이터프레임의 행 인덱스와 열 이름을 [행, 열] 형식의 좌표로 입력하여 원소 위치 지정.
#
# 원소가 위치하는 행과 열의 좌표를 입력하면 된다.
#
# 1개의 행과 2개 이상의 열을 선택하거나 그 반대일 경우 시리즈가 반환.
# 2개 이상의 행과 2개 이상의 열 선택 시 데이터프레임 객체 반환
#
#     - 인덱스 이름 : DataFrame.loc[행 인덱스, 열 이름]
#     - 정수 위치 인덱스 : DataFrame.iloc[행 번호, 열 번호]
#
#
# 딕셔너리를 데이터프레임 df로 변환하고, set_index() 메소드를 적용하여 '이름' 열을 새로운 행 인덱스로 지정한다.

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)

df.set_index('이름', inplace=True)
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 데이터프레임 특정 원소 1개 선택 '서준'의 '음악'점수
a = df.loc['서준','음악']
a
# Out:
# 85

# %%
b = df.iloc[0, 2]
b
# Out:
# 85

# %%
# 특정 원소 2개 이상 선택 ('서준'의 '음악'과 '체육'점수)
c = df.loc['서준', ['음악','체육']]
c
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
d = df.iloc[0, [2,3]]
d
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
e = df.loc['서준', '음악':'체육']
e
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
f = df.iloc[0, 2:]
f
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %% [markdown]
# * 열 추가
#
#         열 추가 : DataFrame['추가하려는 열 이름'] = 데이터 값
#
# 이렇게 넣으면 모든 행에 동일한 값이 입력 된다.

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df['국어'] = 80
df
# Out:
#    이름  수학  영어   음악   체육  국어
# 0  서준  90  98   85  100  80
# 1  우현  80  89   95   90  80
# 2  인아  70  95  100   90  80

# %% [markdown]
# * 행 추가
#
# 추가하려는 행 이름과 데이터 값을 loc 인덱서를 사용하여 입력. 하나의 데이터 값을 입력하거나, 열의 개수에 맞게 배열 형태로 여러 개의 값을 입력할 수 있다.
#
#          행 추가 : DataFrame.loc['새로운 행 이름'] = 데이터 값 (또는 배열)
#
# 데이터프레임에 새로운 행을 추가 할 때 기존 행 인덱스와 겹치지 않는 새로운 인덱스를 사용한다. 중복되는 경우 새로운 행을 추가하지 않고 기존 행의 원소값이 변경된다.
#
# 행 인덱스를 지정할 때 기존 인덱스의 순서를 따르지 않아도 된다.

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'이름' : ['서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df.loc[3] = 0
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
# 3   0   0   0    0    0

# %%
df.loc[4] = ['동규', 90, 80, 70, 60]
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
# 3   0   0   0    0    0
# 4  동규  90  80   70   60

# %%
df.loc['행5'] = df.loc[3]
df
# Out:
#     이름  수학  영어   음악   체육
# 0   서준  90  98   85  100
# 1   우현  80  89   95   90
# 2   인아  70  95  100   90
# 3    0   0   0    0    0
# 4   동규  90  80   70   60
# 행5   0   0   0    0    0

# %%
df.loc[10] = df.loc[4]
df
# Out:
#     이름  수학  영어   음악   체육
# 0   서준  90  98   85  100
# 1   우현  80  89   95   90
# 2   인아  70  95  100   90
# 3    0   0   0    0    0
# 4   동규  90  80   70   60
# 행5   0   0   0    0    0
# 10  동규  90  80   70   60

# %% [markdown]
# * 원소 값 변경
#
# 데이터프레임의 특정 원소를 선택하고 새로운 데이터 값을 지정.
#
#         원소 값 변경 : DataFrame 객체 일부분 또는 원소를 선택  = 새로운 값

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)

# %%
# '이름' 열을 새로운 인덱스로 지정, df 객체에 반영
df.set_index('이름', inplace=True)
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# df의 특정 원소 변경 : '서준'의 '체육' 점수
df.iloc[0][3] = 80
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98   85  80
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
df.loc['서준']['체육'] = 90
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98   85  90
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
df.loc['서준', '체육'] = 90
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98   85  90
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
# df의 원소 여러 개를 변경, 서준의 음악, 체육 점수를 50으로.
df.loc['서준', ['음악','체육']] = 50
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98   50  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %%
df.loc['서준', ['음악','체육']] =100, 50 # 각 점수 지정
df
# Out:
#     수학  영어   음악  체육
# 이름
# 서준  90  98  100  50
# 우현  80  89   95  90
# 인아  70  95  100  90

# %% [markdown]
# * 행, 열 위치 바꾸기
#
# 데이터프레임의 행과 열을 서로 맞바꾸는 방법 = 선형대수학의 전치행렬과 같은 개념
#
#         행, 열 바꾸기 : DataFrame.transpose() or DataFrame.T

# %%
import pandas as pd

# DataFrame() 함수로 데이터프레임 변환. 변수 df에 저장 
exam_data = {'이름' : [ '서준', '우현', '인아'],
             '수학' : [ 90, 80, 70],
             '영어' : [ 98, 89, 95],
             '음악' : [ 85, 95, 100],
             '체육' : [ 100, 90, 90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90

# %%
df = df.transpose()
df
# Out:
#       0   1    2
# 이름   서준  우현   인아
# 수학   90  80   70
# 영어   98  89   95
# 음악   85  95  100
# 체육  100  90   90

# %%
df = df.T
df
# Out:
#    이름  수학  영어   음악   체육
# 0  서준  90  98   85  100
# 1  우현  80  89   95   90
# 2  인아  70  95  100   90
